# %% [markdown]
# #### Generating graphs

# %%
import os
import numpy as np
import wfdb
from wfdb import processing
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nsr_record = wfdb.rdrecord('data/nsrdb/16265', sampto=700)

# %%
nsr_record.p_signal[:, 0]

plt.figure(figsize=(14,4))
plt.plot(nsr_record.p_signal[:, 0], color='black')
plt.axis('off')
plt.show()
