# %% [markdown]
# #### Download script
#
# Run this notebook to download the ECG data from PhysioNet

# %%
import os
import numpy as np
import wfdb
from wfdb import processing
from tqdm import tqdm

# %% [markdown]
# #### Download Databases

# %%
dbs = ['chfdb', 'chf2db', 'fantasia', 'nsrdb', 'nsr2db']
db_records = {}

for db in dbs:
    wfdb.dl_database(db, os.getcwd() + f'/data/{db}')
    db_records[db] = wfdb.get_record_list(db)
# Out:
# Generating record list for: chf01
# Generating record list for: chf02
# Generating record list for: chf03
# Generating record list for: chf04
# Generating record list for: chf05
# Generating record list for: chf06
# Generating record list for: chf07
# Generating record list for: chf08
# Generating record list for: chf09
# Generating record list for: chf10
# Generating record list for: chf11
# Generating record list for: chf12
# Generating record list for: chf13
# Generating record list for: chf14
# Generating record list for: chf15
# Generating list of all files for: chf01
# Generating list of all files for: chf02
# Generating list of all files for: chf03
# Generating list of all files for: chf04
# Generating list of all files for: chf05
# Generating list of all files for: chf06
# Generating list of all files for: chf07
# Generating list of all files for: chf08
# Generating list of all files for: chf09
# Generating list of all files for: chf10
# Generating list of all files for: chf11
# Generating list of all files for: chf12
# Generating list of all files for: chf13
# Generating list of all files for: chf14
# Generating list of all files for: chf15
# Downloading files...
# Finished downloading files
# Generating record list for: chf201
# Generating record list for: chf202
# Generating record list for: chf203
# Generating record list for: chf204
# Generating record list for: chf205
# Generating record list for: chf206
# Generating record list for: chf207
# Generating record list for: chf208
# Generating record list for: chf209
# Generating record list for: chf210
# Generating record list for: chf211
# Generating record list for: chf212
# Generating record list for: chf213
# Generating record list for: chf214
# Generating record list for: chf215
# Generating record list for: chf216
# Generating record list for: chf217
# Generating record list for: chf218
# Generating record list for: chf219
# Generating record list for: chf220
# Generating record list for: chf221
# Generating record list for: chf222
# Generating record list for: chf223
# Generating record list for: chf224
# Generating record list for: chf225
# Generating record list for: chf226
# Generating record list for: chf227
# Generating record list for: chf228
# Generating record list for: chf229
# Generating list of all files for: chf201
# Generating list of all files for: chf202
# Generating list of all files for: chf203
# Generating list of all files for: chf204
# Generating list of all files for: chf205
# Generating list of all files for: chf206
# Generating list of all files for: chf207
# Generating list of all files for: chf208
# Generating list of all files for: chf209
# Generating list of all files for: chf210
# Generating list of all files for: chf211
# Generating list of all files for: chf212
# Generating list of all files for: chf213
# Generating list of all files for: chf214
# Generating list of all files for: chf215
# Generating list of all files for: chf216
# Generating list of all files for: chf217
# Generating list of all files for: chf218
# Generating list of all files for: chf219
# Generating list of all files for: chf220
# Generating list of all files for: chf221
# Generating list of all files for: chf222
# Generating list of all files for: chf223
# Generating list of all files for: chf224
# Generating list of all files for: chf225
# Generating list of all files for: chf226
# Generating list of all files for: chf227
# Generating list of all files for: chf228
# Generating list of all files for: chf229
# Downloading files...
# Finished downloading files
# Generating record list for: f1o01
# Generating record list for: f1o02
# Generating record list for: f1o03
# Generating record list for: f1o04
# Generating record list for: f1o05
# Generating record list for: f1o06
# Generating record list for: f1o07
# Generating record list for: f1o08
# Generating record list for: f1o09
# Generating record list for: f1o10
# Generating record list for: f1y01
# Generating record list for: f1y02
# Generating record list for: f1y03
# Generating record list for: f1y04
# Generating record list for: f1y05
# Generating record list for: f1y06
# Generating record list for: f1y07
# Generating record list for: f1y08
# Generating record list for: f1y09
# Generating record list for: f1y10
# Generating record list for: f2o01
# Generating record list for: f2o02
# Generating record list for: f2o03
# Generating record list for: f2o04
# Generating record list for: f2o05
# Generating record list for: f2o06
# Generating record list for: f2o07
# Generating record list for: f2o08
# Generating record list for: f2o09
# Generating record list for: f2o10
# Generating record list for: f2y01
# Generating record list for: f2y02
# Generating record list for: f2y03
# Generating record list for: f2y04
# Generating record list for: f2y05
# Generating record list for: f2y06
# Generating record list for: f2y07
# Generating record list for: f2y08
# Generating record list for: f2y09
# Generating record list for: f2y10
# Generating list of all files for: f1o01
# Generating list of all files for: f1o02
# Generating list of all files for: f1o03
# Generating list of all files for: f1o04
# Generating list of all files for: f1o05
# Generating list of all files for: f1o06
# Generating list of all files for: f1o07
# Generating list of all files for: f1o08
# Generating list of all files for: f1o09
# Generating list of all files for: f1o10
# Generating list of all files for: f1y01
# Generating list of all files for: f1y02
# Generating list of all files for: f1y03
# Generating list of all files for: f1y04
# Generating list of all files for: f1y05
# Generating list of all files for: f1y06
# Generating list of all files for: f1y07
# Generating list of all files for: f1y08
# Generating list of all files for: f1y09
# Generating list of all files for: f1y10
# Generating list of all files for: f2o01
# Generating list of all files for: f2o02
# Generating list of all files for: f2o03
# Generating list of all files for: f2o04
# Generating list of all files for: f2o05
# Generating list of all files for: f2o06
# Generating list of all files for: f2o07
# Generating list of all files for: f2o08
# Generating list of all files for: f2o09
# Generating list of all files for: f2o10
# Generating list of all files for: f2y01
# Generating list of all files for: f2y02
# Generating list of all files for: f2y03
# Generating list of all files for: f2y04
# Generating list of all files for: f2y05
# Generating list of all files for: f2y06
# Generating list of all files for: f2y07
# Generating list of all files for: f2y08
# Generating list of all files for: f2y09
# Generating list of all files for: f2y10
# Downloading files...
# Finished downloading files
# Generating record list for: 16265
# Generating record list for: 16272
# Generating record list for: 16273
# Generating record list for: 16420
# Generating record list for: 16483
# Generating record list for: 16539
# Generating record list for: 16773
# Generating record list for: 16786
# Generating record list for: 16795
# Generating record list for: 17052
# Generating record list for: 17453
# Generating record list for: 18177
# Generating record list for: 18184
# Generating record list for: 19088
# Generating record list for: 19090
# Generating record list for: 19093
# Generating record list for: 19140
# Generating record list for: 19830
# Generating list of all files for: 16265
# Generating list of all files for: 16272
# Generating list of all files for: 16273
# Generating list of all files for: 16420
# Generating list of all files for: 16483
# Generating list of all files for: 16539
# Generating list of all files for: 16773
# Generating list of all files for: 16786
# Generating list of all files for: 16795
# Generating list of all files for: 17052
# Generating list of all files for: 17453
# Generating list of all files for: 18177
# Generating list of all files for: 18184
# Generating list of all files for: 19088
# Generating list of all files for: 19090
# Generating list of all files for: 19093
# Generating list of all files for: 19140
# Generating list of all files for: 19830
# Downloading files...
# Finished downloading files
# Generating record list for: nsr001
# Generating record list for: nsr002
# Generating record list for: nsr003
# Generating record list for: nsr004
# Generating record list for: nsr005
# Generating record list for: nsr006
# Generating record list for: nsr007
# Generating record list for: nsr008
# Generating record list for: nsr009
# Generating record list for: nsr010
# Generating record list for: nsr011
# Generating record list for: nsr012
# Generating record list for: nsr013
# Generating record list for: nsr014
# Generating record list for: nsr015
# Generating record list for: nsr016
# Generating record list for: nsr017
# Generating record list for: nsr018
# Generating record list for: nsr019
# Generating record list for: nsr020
# Generating record list for: nsr021
# Generating record list for: nsr022
# Generating record list for: nsr023
# Generating record list for: nsr024
# Generating record list for: nsr025
# Generating record list for: nsr026
# Generating record list for: nsr027
# Generating record list for: nsr028
# Generating record list for: nsr029
# Generating record list for: nsr030
# Generating record list for: nsr031
# Generating record list for: nsr032
# Generating record list for: nsr033
# Generating record list for: nsr034
# Generating record list for: nsr035
# Generating record list for: nsr036
# Generating record list for: nsr037
# Generating record list for: nsr038
# Generating record list for: nsr039
# Generating record list for: nsr040
# Generating record list for: nsr041
# Generating record list for: nsr042
# Generating record list for: nsr043
# Generating record list for: nsr044
# Generating record list for: nsr045
# Generating record list for: nsr046
# Generating record list for: nsr047
# Generating record list for: nsr048
# Generating record list for: nsr049
# Generating record list for: nsr050
# Generating record list for: nsr051
# Generating record list for: nsr052
# Generating record list for: nsr053
# Generating record list for: nsr054
# Generating list of all files for: nsr001
# Generating list of all files for: nsr002
# Generating list of all files for: nsr003
# Generating list of all files for: nsr004
# Generating list of all files for: nsr005
# Generating list of all files for: nsr006
# Generating list of all files for: nsr007
# Generating list of all files for: nsr008
# Generating list of all files for: nsr009
# Generating list of all files for: nsr010
# Generating list of all files for: nsr011
# Generating list of all files for: nsr012
# Generating list of all files for: nsr013
# Generating list of all files for: nsr014
# Generating list of all files for: nsr015
# Generating list of all files for: nsr016
# Generating list of all files for: nsr017
# Generating list of all files for: nsr018
# Generating list of all files for: nsr019
# Generating list of all files for: nsr020
# Generating list of all files for: nsr021
# Generating list of all files for: nsr022
# Generating list of all files for: nsr023
# Generating list of all files for: nsr024
# Generating list of all files for: nsr025
# Generating list of all files for: nsr026
# Generating list of all files for: nsr027
# Generating list of all files for: nsr028
# Generating list of all files for: nsr029
# Generating list of all files for: nsr030
# Generating list of all files for: nsr031
# Generating list of all files for: nsr032
# Generating list of all files for: nsr033
# Generating list of all files for: nsr034
# Generating list of all files for: nsr035
# Generating list of all files for: nsr036
# Generating list of all files for: nsr037
# Generating list of all files for: nsr038
# Generating list of all files for: nsr039
# Generating list of all files for: nsr040
# Generating list of all files for: nsr041
# Generating list of all files for: nsr042
# Generating list of all files for: nsr043
# Generating list of all files for: nsr044
# Generating list of all files for: nsr045
# Generating list of all files for: nsr046
# Generating list of all files for: nsr047
# Generating list of all files for: nsr048
# Generating list of all files for: nsr049
# Generating list of all files for: nsr050
# Generating list of all files for: nsr051
# Generating list of all files for: nsr052
# Generating list of all files for: nsr053
# Generating list of all files for: nsr054
# Downloading files...
# Finished downloading files

# %% [markdown]
# #### Extract RR Intervals

# %%
def extract(db, record, ext='ecg'):
    return processing.ann2rr(f'data/{db}/{record}', ext, format='s')

# %%
rcd_dbs = ['chfdb', 'fantasia', 'nsrdb']
ann_dbs = ['chf2db', 'nsr2db']
rr_records = {}

# %%
rr_records['chfdb'] = {}
for record in tqdm(db_records['chfdb']):
    rr_records['chfdb'][record] = extract('chfdb', record)
# Out:
# 100%|██████████| 15/15 [00:05<00:00,  2.80it/s]

# %%
rr_records['fantasia'] = {}
for record in tqdm(db_records['fantasia']):
    rr_records['fantasia'][record] = extract('fantasia', record)
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 42.42it/s]

# %%
rr_records['nsrdb'] = {}
for record in tqdm(db_records['nsrdb']):
    rr_records['nsrdb'][record] = extract('nsrdb', record, ext='atr')
# Out:
# 100%|██████████| 18/18 [00:06<00:00,  2.69it/s]

# %%
rr_records['chf2db'] = {}
for record in tqdm(db_records['chf2db']):
    rr_records['chf2db'][record] = extract('chf2db', record)
# Out:
# 100%|██████████| 29/29 [00:10<00:00,  2.71it/s]

# %%
rr_records['nsr2db'] = {}
for record in tqdm(db_records['nsr2db']):
    rr_records['nsr2db'][record] = extract('nsr2db', record)
# Out:
# 100%|██████████| 54/54 [00:19<00:00,  2.80it/s]

# %% [markdown]
# ##### Save RR intervals to file

# %%
for db in rr_records.keys():
    if not os.path.exists(f'data/{db}/rr'):
        os.makedirs(f'data/{db}/rr')
    records = rr_records[db]
    for record in records.keys():
        rr = records[record]
        np.savetxt(f'data/{db}/rr/{record}.txt', rr)
